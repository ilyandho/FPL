# %%
# %pip install beautifulsoup4
# %pip install MechanicalSoup
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/ilyandho/.conda/envs/FPL/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /home/ilyandho/.conda/envs/FPL/lib/python3.11/site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: MechanicalSoup in /home/ilyandho/.conda/envs/FPL/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: requests>=2.22.0 in /home/ilyandho/.conda/envs/FPL/lib/python3.11/site-packages (from MechanicalSoup) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.7 in /home/ilyandho/.conda/envs/FPL/lib/python3.11/site-packages (from MechanicalSoup) (4.12.2)
# Requirement already satisfied: lxml in /home/ilyandho/.conda/envs/FPL/lib/python3.11/site-packages (from MechanicalSoup) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /home/ilyandho/.conda/envs/FPL/lib/python3.11/site-packages (from beautifulsoup4>=4.7->MechanicalSoup) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ilyandho/.conda/envs/FPL/lib/python3.11/site-packages (from requests>=2.22.0->MechanicalSoup) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ilyandho/.conda/envs/FPL/lib/python3.11/site-packages (from requests>=2.22.0->MechanicalSoup) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ilyandho/.conda/envs/FPL/lib/python3.11/site-packages (from requests>=2.22.0->MechanicalSoup) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ilyandho/.conda/envs/FPL/lib/python3.11/site-packages (from requests>=2.22.0->MechanicalSoup) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
# import mechanicalsoup

from urllib.request import  urlopen
hdr = {'User-Agent': 'Mozilla/5.0'}

# %% [markdown]
# ### Set up browser

# %%
browser = mechanicalsoup.StatefulBrowser(soup_config={'features':'parser.html'})
browser.set_user_agent('my-awesome-script')

# %% [markdown]
# ### Single match stats

# %%
whill = "https://sports.williamhill.com/betting/en-gb/football/OB_EV29359802/wolves-vs-tottenham"
# page = browser.get(whill)
# page

page = urlopen(whill)
html = page
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# /home/ilyandho/Dev/Data Science/FPL/scrapper/init.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/home/ilyandho/Dev/Data%20Science/FPL/scrapper/init.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> whill = "https://sports.williamhill.com/betting/en-gb/football/OB_EV29359802/wolves-vs-tottenham"
# ----> <a href='vscode-notebook-cell:/home/ilyandho/Dev/Data%20Science/FPL/scrapper/init.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> page = browser.get(whill)
#       <a href='vscode-notebook-cell:/home/ilyandho/Dev/Data%20Science/FPL/scrapper/init.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> page
#
# File ~/.conda/envs/FPL/lib/python3.11/site-packages/mechanicalsoup/browser.py:152, in Browser.get(self, *args, **kwargs)
#     150 if self.raise_on_404 and response.status_code == 404:
#     151     raise LinkNotFoundError()
# --> 152 Browser.add_soup(response, self.soup_config)
#     153 return response
#
# File ~/.conda/envs/FPL/lib/python3.11/site-packages/mechanicalsoup/browser.py:91, in Browser.add_soup(response, soup_config)
#      87     # See https://www.w3.org/International/questions/qa-html-encoding-declarations.en#httphead  # noqa: E501
#      88     # > The HTTP header has a higher precedence than the in-document
#      89     # > meta declarations.
#      90     encoding = http_encoding if http_encoding else html_encoding
# ---> 91     response.soup = bs4.BeautifulSoup(
#      92         response.content,
#      93         from_encoding=encoding,
#      94         **soup_config
#      95     )
#      96 else:
#      97     response.soup = None
#
# File ~/.conda/envs/FPL/lib/python3.11/site-packages/bs4/__init__.py:250, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     248     builder_class = builder_registry.lookup(*features)
#     249     if builder_class is None:
# --> 250         raise FeatureNotFound(
#     251             "Couldn't find a tree builder with the features you "
#     252             "requested: %s. Do you need to install a parser library?"
#     253             % ",".join(features))
#     255 # At this point either we have a TreeBuilder instance in
#     256 # builder, or we have a builder_class that we can instantiate
#     257 # with the remaining **kwargs.
#     258 if builder is None:
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: parser.html. Do you need to install a parser library?

# %%
players = page.soup.find_all("article",["cpt-goalscorer__player"])

# %%
player = players[0].findChild('h3').get_text()

first = players[0].find_all('li')[0].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
anytime = players[0].find_all('li')[1].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
last = players[0].find_all('li')[2].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
two_or_more = players[0].find_all('li')[3].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
hattrick = players[0].find_all('li')[4].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
first_and_last = players[0].find_all('li')[5].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
first_or_last = players[0].find_all('li')[6].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")

details = [player,{"first":[first[0],first[1]]} ,
        {"anytime":[anytime[0],anytime[1]]},
        {"last":[last[0],last[1]]},
        {"two_or_more":[two_or_more[0],two_or_more[1]]},
        {"hattrick":[hattrick[0],hattrick[1]]},
        {"first_and_last":[first_and_last[0],first_and_last[1]]},
        {"first_or_last":[first_or_last[0],first_or_last[1]]}
        ]
details

# for tag in players:   # print(ta("h2"))
# Out:
# ['Nathan Fraser',
#  {'first': ['7', '1']},
#  {'anytime': ['13', '5']},
#  {'last': ['7', '1']},
#  {'two_or_more': ['16', '1']},
#  {'hattrick': ['90', '1']},
#  {'first_and_last': ['22', '1']},
#  {'first_or_last': ['9', '2']}]

# %%
players_details = []
for index,tag in enumerate(players):
    # Get player name
    player = tag.findChild('h3').get_text()

    # Get players odds
    if(index+1 == len(players)):
        # For the no goal scored odd
        first = tag.find_all('li')[0].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
        details = [player,{"first":[first[0],first[1]]}]

        players_details.append(details)
        continue
    else:
        first = tag.find_all('li')[0].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
        anytime = tag.find_all('li')[1].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
        last = players[0].find_all('li')[2].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
        two_or_more = players[0].find_all('li')[3].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
        hattrick = players[0].find_all('li')[4].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
        first_and_last = players[0].find_all('li')[5].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
        first_or_last = players[0].find_all('li')[6].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")

        details = [player,{"first":[first[0],first[1]]} ,
            {"anytime":[anytime[0],anytime[1]]},
            {"last":[last[0],last[1]]},
            {"two_or_more":[two_or_more[0],two_or_more[1]]},
            {"hattrick":[hattrick[0],hattrick[1]]},
            {"first_and_last":[first_and_last[0],first_and_last[1]]},
            {"first_or_last":[first_or_last[0],first_or_last[1]]}
            ]
        players_details.append(details)

len(players_details)
# Out:
# 39

# %%
for index,tag in enumerate(players):
    if(index+1 == len(players)):
        print('No goal')
        continue
    else:
        print( (index,'-', len(players)),tag.findChild("h3"))
# Out:
# (0, '-', 39) <h3>Nathan Fraser</h3>
# (1, '-', 39) <h3>Sasa Kalajdzic</h3>
# (2, '-', 39) <h3>Fabio Silva</h3>
# (3, '-', 39) <h3>Pablo Sarabia</h3>
# (4, '-', 39) <h3>Matheus Cunha</h3>
# (5, '-', 39) <h3>Hwang Hee-chan</h3>
# (6, '-', 39) <h3>Craig Dawson</h3>
# (7, '-', 39) <h3>Boubacar Traore</h3>
# (8, '-', 39) <h3>Tommy Doyle</h3>
# (9, '-', 39) <h3>Jean-Ricner Bellegarde</h3>
# (10, '-', 39) <h3>Mario Lemina</h3>
# (11, '-', 39) <h3>Matt Doherty</h3>
# (12, '-', 39) <h3>Joao Gomes</h3>
# (13, '-', 39) <h3>Rayan Ait Nouri</h3>
# (14, '-', 39) <h3>Jonny Otto</h3>
# (15, '-', 39) <h3>Max Kilman</h3>
# (16, '-', 39) <h3>Toti</h3>
# (17, '-', 39) <h3>Nelson Semedo</h3>
# (18, '-', 39) <h3>Santiago Bueno</h3>
# (19, '-', 39) <h3>Heung-min Son</h3>
# (20, '-', 39) <h3>Richarlison</h3>
# (21, '-', 39) <h3>James Maddison</h3>
# (22, '-', 39) <h3>Brennan Johnson</h3>
# (23, '-', 39) <h3>Jamie Donley</h3>
# (24, '-', 39) <h3>Alejo Veliz</h3>
# (25, '-', 39) <h3>Rodrigo Bentancur</h3>
# (26, '-', 39) <h3>Bryan Gil</h3>
# (27, '-', 39) <h3>Giovani Lo Celso</h3>
# (28, '-', 39) <h3>Dejan Kulusevski</h3>
# (29, '-', 39) <h3>Pape Matar Sarr</h3>
# (30, '-', 39) <h3>Pierre-Emile Hojbjerg</h3>
# (31, '-', 39) <h3>Pedro Porro</h3>
# (32, '-', 39) <h3>Eric Dier</h3>
# (33, '-', 39) <h3>Oliver Skipp</h3>
# (34, '-', 39) <h3>Yves Bissouma</h3>
# (35, '-', 39) <h3>Ben Davies</h3>
# (36, '-', 39) <h3>Emerson Royal</h3>
# (37, '-', 39) <h3>Ashley Phillips</h3>
# No goal

# %% [markdown]
# ### Function for a single match

# %% [markdown]
# #### Get All Matches in Game Week

# %%
premLeague = "https://sports.williamhill.com/betting/en-gb/football/competitions/OB_TY295/English-Premier-League/matches/OB_MGMB/Match-Betting"
# match_page = browser.get(premLeague)
# print(match_page.soup)


_page = urlopen(premLeague)
html = _page.read().decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /home/ilyandho/Dev/Data Science/FPL/scrapper/init.ipynb Cell 13 line 6
#       <a href='vscode-notebook-cell:/home/ilyandho/Dev/Data%20Science/FPL/scrapper/init.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> premLeague = "https://sports.williamhill.com/betting/en-gb/football/competitions/OB_TY295/English-Premier-League/matches/OB_MGMB/Match-Betting"
#       <a href='vscode-notebook-cell:/home/ilyandho/Dev/Data%20Science/FPL/scrapper/init.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> # match_page = browser.get(premLeague)
#       <a href='vscode-notebook-cell:/home/ilyandho/Dev/Data%20Science/FPL/scrapper/init.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> # print(match_page.soup)
# ----> <a href='vscode-notebook-cell:/home/ilyandho/Dev/Data%20Science/FPL/scrapper/init.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> _page = urlopen(premLeague)
#       <a href='vscode-notebook-cell:/home/ilyandho/Dev/Data%20Science/FPL/scrapper/init.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> html = _page.read().decode("utf-8")
#
# File ~/.conda/envs/FPL/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/.conda/envs/FPL/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~/.conda/envs/FPL/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~/.conda/envs/FPL/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File ~/.conda/envs/FPL/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/.conda/envs/FPL/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
def fetch_site(teams):
    whill = "https://sports.williamhill.com/betting/en-gb/football/OB_EV29359802/wolves-vs-tottenham"
    page = browser.get(whill)
    page

    players = page.soup.find_all("article",["cpt-goalscorer__player"])


fetch_site('tenm')
# Out:
# [<article class="cpt-goalscorer__player"><header class="cpt-goalscorer__title"><h3>Nathan Fraser</h3></header><ul class="cpt-goalscorer__list-odds"><li class="odds-market-1" data-betinrun="false" data-displayed="true" data-entityid="OB_MA1319797665" data-status="A"><button aria-label="Nathan Fraser at 7/1" class="btn betbutton oddsbutton market__button" data-denom="1" data-displayed="true" data-entityid="OB_OU4450344809" data-event="OB_EV29359802" data-market="OB_MA1319797665" data-name="Nathan Fraser" data-num="7" data-odds="7/1" data-player="Nathan Fraser" data-status="A" id="OB_OU4450344809"><span class="selectiondetails" data-market-group="First Goalscorer" data-odds="7/1" data-outcome="" data-player="Nathan Fraser"><span class="selectionplayer">Nathan Fraser</span></span> <span data-odds-change=""></span> <span class="icon"></span></button></li><li class="odds-market-2" data-betinrun="false" data-displayed="true" data-entityid="OB_MA1319797649" data-status="A"><button aria-label="Nathan Fraser at 13/5" class="btn betbutton oddsbutton market__button" data-denom="5" data-displayed="true" data-entityid="OB_OU4450344282" data-event="OB_EV29359802" data-market="OB_MA1319797649" data-name="Nathan Fraser" data-num="13" data-odds="13/5" data-player="Nathan Fraser" data-status="A" id="OB_OU4450344282"><span class="selectiondetails" data-market-group="Anytime Goalscorer" data-odds="13/5" data-outcome="" data-player="Nathan Fraser"><span class="selectionplayer">Nathan Fraser</span></span> <span data-odds-change=""></span> <span class="icon"></span></button></li><li class="odds-market-3" data-betinrun="false" data-displayed="true" data-entityid="OB_MA1319797632" data-status="A"><button aria-label="Nathan Fraser at 7/1" class="btn betbutton oddsbutton market__button" data-denom="1" data-displayed="true" data-entityid="OB_OU4450343868" data-event="OB_EV29359802" data-market="OB_MA1319797632" data-name="Nathan Fraser" data-num="7" data-odds="7/1" data-player="Nathan Fraser" data-status="A" id="OB_OU4450343868"><span class="selectiondetails" data-market-group="Last Goalscorer" data-odds="7/1" data-outcome="" data-player="Nathan Fraser"><span class="selectionplayer">Nathan Fraser</span></span> <span data-odds-change=""></span> <span class="icon"></span></button></li><li class="odds-market-4" data-betinrun="false" data-displayed="true" data-entityid="OB_MA1319797634" data-status="A"><button aria-label="Nathan Fraser at 16/1" class="btn betbutton oddsbutton market__button" data-denom="1" data-displayed="true" data-entityid="OB_OU4450343896" data-event="OB_EV29359802" data-market="OB_MA1319797634" data-name="Nathan Fraser" data-num="16" data-odds="16/1" data-player="Nathan Fraser" data-status="A" id="OB_OU4450343896"><span class="selectiondetails" data-market-group="Player To Score 2 Or More" data-odds="16/1" data-outcome="" data-player="Nathan Fraser"><span class="selectionplayer">Nathan Fraser</span></span> <span data-odds-change=""></span> <span class="icon"></span></button></li><li class="odds-market-5" data-betinrun="false" data-displayed="true" data-entityid="OB_MA1319797640" data-status="A"><button aria-label="Nathan Fraser at 90/1" class="btn betbutton oddsbutton market__button" data-denom="1" data-displayed="true" data-entityid="OB_OU4450344103" data-event="OB_EV29359802" data-market="OB_MA1319797640" data-name="Nathan Fraser" data-num="90" data-odds="90/1" data-player="Nathan Fraser" data-status="A" id="OB_OU4450344103"><span class="selectiondetails" data-market-group="Hatrick" data-odds="90/1" data-outcome="" data-player="Nathan Fraser"><span class="selectionplayer">Nathan Fraser</span></span> <span data-odds-change=""></span> <span class="icon"></span></button></li><li class="odds-market-6" data-betinrun="false" data-displayed="true" data-entityid="OB_MA1319797637" data-status="A"><button aria-label="Nathan Fraser at 22/1" class="btn betbutton oddsbutton market__button" data-denom="1" data-displayed="true" data-entityid="OB_OU445 ...

# %%
def get_player_stats(teams):


    players_details = []
    for index,tag in enumerate(players):
        # Get player name
        player = tag.findChild('h3').get_text()

        # Get players odds
        if(index+1 == len(players)):
            # For the no goal scored odd
            first = tag.find_all('li')[0].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
            details = [player,{"first":[first[0],first[1]]}]

            players_details.append(details)
            continue
        else:
            first = tag.find_all('li')[0].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
            anytime = tag.find_all('li')[1].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
            last = players[0].find_all('li')[2].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
            two_or_more = players[0].find_all('li')[3].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
            hattrick = players[0].find_all('li')[4].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
            first_and_last = players[0].find_all('li')[5].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")
            first_or_last = players[0].find_all('li')[6].find_all("span",['selectiondetails'])[0].get("data-odds").split("/")

            details = [player,{"first":[first[0],first[1]]} ,
                {"anytime":[anytime[0],anytime[1]]},
                {"last":[last[0],last[1]]},
                {"two_or_more":[two_or_more[0],two_or_more[1]]},
                {"hattrick":[hattrick[0],hattrick[1]]},
                {"first_and_last":[first_and_last[0],first_and_last[1]]},
                {"first_or_last":[first_or_last[0],first_or_last[1]]}
                ]
            players_details.append(details)


    return players_details
